# %% [markdown]
# <a href="https://colab.research.google.com/github/ivaibhavi17/Pandas_python/blob/main/pandas_python_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['vaibhavi','manthan','shunham','krishna'],
    "age":[19,18,23,25],
    "marks":[99,98,77,89],
    "city":['ahmedabad','gandhinagar','vadodara','rajkot']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#        name  age  marks         city
# 0  vaibhavi   19     99    ahmedabad
# 1   manthan   18     98  gandhinagar
# 2   shunham   23     77     vadodara
# 3   krishna   25     89       rajkot

# %%
df.head(2)
# Out:
#        name  age  marks         city
# 0  vaibhavi   19     99    ahmedabad
# 1   manthan   18     98  gandhinagar

# %%
df.tail(2)
# Out:
#       name  age  marks      city
# 2  shunham   23     77  vadodara
# 3  krishna   25     89    rajkot

# %%
df.describe()
# Out:
#              age      marks
# count   4.000000   4.000000
# mean   21.250000  90.750000
# std     3.304038  10.210289
# min    18.000000  77.000000
# 25%    18.750000  86.000000
# 50%    21.000000  93.500000
# 75%    23.500000  98.250000
# max    25.000000  99.000000

# %%
df.index=['First','Second','Third','Fourth']
df
# Out:
#             name  age  marks         city
# First   vaibhavi   19     99    ahmedabad
# Second   manthan   18     98  gandhinagar
# Third    shunham   23     77     vadodara
# Fourth   krishna   25     89       rajkot

# %%
ser = pd.Series(np.random.rand(4))
ser
# Out:
# 0    0.401877
# 1    0.368493
# 2    0.444219
# 3    0.437223
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(5,5),index=np.arange(5))
newdf
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.787478  0.390035  0.568272  0.249589  0.408412
# 1  0.796567  0.354117  0.858618  0.264882  0.066955
# 2  0.361349  0.906647  0.081470  0.566231  0.867589
# 3  0.833217  0.281144  0.071868  0.595824  0.457627
# 4  0.631680  0.994809  0.905605  0.149787  0.677259

# %%
newdf.describe()
# Out:
#                0          1          2          3          4
# count  15.000000  15.000000  15.000000  15.000000  15.000000
# mean    0.485294   0.464025   0.410730   0.489552   0.451302
# std     0.276892   0.290948   0.285807   0.338322   0.300107
# min     0.049709   0.049889   0.052505   0.052967   0.033321
# 25%     0.256670   0.260515   0.165683   0.137277   0.219780
# 50%     0.498588   0.396501   0.307490   0.518068   0.367707
# 75%     0.736145   0.741533   0.658852   0.789124   0.752259
# max     0.871727   0.933643   0.839448   0.990882   0.846142

# %%
newdf[0][0]="vaibhavi"
newdf
# Out:
#            0         1         2         3         4
# 0   vaibhavi  0.731446  0.766651  0.832438  0.033321
# 1   0.239569  0.428275  0.307490  0.133129  0.220048
# 2   0.855595  0.893920  0.732756  0.680567  0.743226
# 3    0.68537  0.305510  0.182285  0.435760  0.761292
# 4   0.385992  0.195003  0.616542  0.990882  0.037834
# 5   0.512681  0.396501  0.839448  0.085143  0.694086
# 6   0.273772  0.049889  0.559920  0.846223  0.367707
# 7   0.862756  0.382097  0.155430  0.124417  0.462779
# 8   0.049709  0.215521  0.067243  0.883396  0.289978
# 9    0.78692  0.077428  0.105873  0.745810  0.846142
# 10  0.357288  0.369084  0.175935  0.052967  0.800435
# 11  0.134602  0.933643  0.282802  0.518068  0.839520
# 12  0.536121  0.751620  0.614912  0.141426  0.278479
# 13  0.498588  0.812743  0.052505  0.208452  0.219511
# 14  0.871727  0.417699  0.701162  0.664611  0.175170

# %%
newdf.to_numpy()
# Out:
# array([['vaibhavi', 0.7314460197044773, 0.7666507150656225,
#         0.8324384347977527, 0.033320504846738985],
#        [0.23956853999339367, 0.42827549808676335, 0.3074900842108814,
#         0.1331286505497875, 0.22004810417238707],
#        [0.8555945228985826, 0.8939197620395025, 0.7327561426261601,
#         0.6805668426308069, 0.7432263891960164],
#        [0.6853698697030581, 0.305509547433771, 0.1822848599375121,
#         0.4357595633900935, 0.7612915150095735],
#        [0.38599170480138345, 0.19500264962437575, 0.61654211164352,
#         0.9908820169330175, 0.03783382248180267],
#        [0.5126813631764042, 0.3965011497851859, 0.8394482390020203,
#         0.08514286765222379, 0.6940861149488451],
#        [0.2737715930711494, 0.04988946860692978, 0.5599202539641462,
#         0.8462226079909085, 0.36770672395623805],
#        [0.8627556968369479, 0.382096904671963, 0.15543048313234542,
#         0.12441667370832088, 0.462779402868994],
# ...

# %%
newdf.sort_index(axis=0 , ascending=False)
# Out:
#           0         1         2         3         4
# 4  0.631680  0.994809  0.905605  0.149787  0.677259
# 3  0.833217  0.281144  0.071868  0.595824  0.457627
# 2  0.361349  0.906647  0.081470  0.566231  0.867589
# 1  0.796567  0.354117  0.858618  0.264882  0.066955
# 0  0.787478  0.390035  0.568272  0.249589  0.408412

# %%
newdf.sort_index(axis=1 , ascending=True)
# Out:
#           0         1         2         3         4
# 0  0.787478  0.390035  0.568272  0.249589  0.408412
# 1  0.796567  0.354117  0.858618  0.264882  0.066955
# 2  0.361349  0.906647  0.081470  0.566231  0.867589
# 3  0.833217  0.281144  0.071868  0.595824  0.457627
# 4  0.631680  0.994809  0.905605  0.149787  0.677259

# %%
newdf.loc[0,0] = 1708
newdf.head(2)
# Out:
#              0         1         2         3         4
# 0  1708.000000  0.390035  0.568272  0.249589  0.408412
# 1     0.796567  0.354117  0.858618  0.264882  0.066955

# %%
newdf.columns= list("ABCDE")
newdf
# Out:
#              A         B         C         D         E
# 0  1708.000000  0.390035  0.568272  0.249589  0.408412
# 1     0.796567  0.354117  0.858618  0.264882  0.066955
# 2     0.361349  0.906647  0.081470  0.566231  0.867589
# 3     0.833217  0.281144  0.071868  0.595824  0.457627
# 4     0.631680  0.994809  0.905605  0.149787  0.677259

# %%
newdf.loc[(newdf['A']< 0.4)]
# Out:
#           A         B        C         D         E
# 2  0.361349  0.906647  0.08147  0.566231  0.867589

# %%
newdf = pd.DataFrame(np.random.rand(5,5),index=np.arange(5))
newdf
newdf.head()
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.627844  0.507043  0.335213  0.564827  0.303816
# 1  0.194133  0.990599  0.162697  0.931357  0.147762
# 2  0.057619  0.820915  0.916314  0.389303  0.636212
# 3  0.825683  0.073130  0.986912  0.698747  0.901215
# 4  0.134290  0.445716  0.966600  0.890118  0.965797

# %%
newdf.loc[:,0].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: 0, dtype: bool

# %%
newdf.shape
# Out:
# (5, 5)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      float64
#  1   1       5 non-null      float64
#  2   2       5 non-null      float64
#  3   3       5 non-null      float64
#  4   4       5 non-null      float64
# dtypes: float64(5)
# memory usage: 240.0 bytes
